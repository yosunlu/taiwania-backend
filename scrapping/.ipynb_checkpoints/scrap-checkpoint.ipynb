# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://sutian.moe.edu.tw/zh-hant/huliok/106/'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

# %%
url = 'https://sutian.moe.edu.tw/zh-hant/huliok/106/'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html.parser') 
table = soup.find_all('table')

# Find all <th> elements (table headers)
titles = soup.find_all('th')  

# Extract text from the <th> elements
table_titles = [title.text.strip() for title in titles]

# Create a DataFrame with the first four titles as headers
headers = table_titles[:4]
df = pd.DataFrame(columns=headers)

# Add an additional 'href' column
df['href'] = None

# %%
def scrapSinglePage(page):
    pageNum = str(page)
    url = 'https://sutian.moe.edu.tw/zh-hant/huliok/106/?iahbe=' + pageNum
    curPage = requests.get(url)
    soup = BeautifulSoup(curPage.text, 'html')
    table = soup.find_all('table')
    
    for row in table[:-1]:
        row_data = row.find_all('td')
        a_tag  = row.find('a')
        href_value = a_tag['href']
        individual_row_data = []
        for data in row_data:
            # Strip and clean the text
            cleaned_text = data.text.strip().replace('\n', '').replace('\t', '').replace('\r', '')
            
            # Find the first period and keep everything up to and including it
            period_index = cleaned_text.find('.')
            if period_index != -1:
                cleaned_text = cleaned_text[:period_index + 1]
        
            individual_row_data.append(cleaned_text)
            
        individual_row_data.append("https://sutian.moe.edu.tw/" + href_value)
        length = len(df)
        df.loc[length] = individual_row_data

# %%
for i in range(20):
    scrapSinglePage(i)

# %%
new_column_name = 'tags'
new_column_data = "slang"  # or you can use a list of values with the same length as the DataFrame

# Insert the new column at position 3 (between the third and fourth columns)
df.insert(4, new_column_name, new_column_data)

# %%
df
# Out:
#       序號              詞目                                                 音讀  \
# 0      1           鴨仔聽雷。                                   Ah-á thiann luî.
# 1      2          愛拚才會贏。                             Ài piànn tsiah ē iânn.
# 2      3        愛媠毋驚流鼻水。                    Ài-suí m̄ kiann lâu phīnn-tsuí.
# 3      4   暗頓減食一口，活甲九十九。  Àm-tǹg kiám tsia̍h tsi̍t kháu, ua̍h kah káu-ts...
# 4      5        翁仔某是相欠債。                        Ang-á-bóo sī sio-khiàm-tsè.
# ..   ...             ...                                                ...
# 375  376     有樣看樣，無樣家己想。           Ū iūnn khuànn iūnn, bô iūnn ka-kī siūnn.
# 376  377    有囝有囝命，無囝天註定。     Ū kiánn ū kiánn miā, bô kiánn thinn tsù-tiānn.
# 377  378          有量就有福。                                  Ū-liōng tō ū hok.
# 378  379  有燒香有保庇，有食藥有行氣。    Ū sio-hiunn ū pó-pì, ū tsia̍h io̍h ū kiânn-khì.
# 379  380      有唐山公，無唐山媽。               Ū Tn̂g-suann kong, bô Tn̂g-suann má.
#
#                                                     釋義   tags  \
# 0    指鴨子聽到雷聲，並不知道是怎麼回事。比喻一個人對所接收的訊息無法理解。比喻一個人對所接收的訊...  slang
# 1                       要努力才會贏。比喻唯有努力奮鬥，才能克服困難，成就一番事業。  slang
# 2    為了展示自己姣好的身材，天氣再冷，寧可挨寒受凍，也不願多穿衣服。常用以揶揄女性愛美，寧可付出...  slang
# 3                     晚餐少吃一口，活到九十九。說明晚餐的食用量少一點，有益身體健康。  slang
# 4    今世有緣結為夫妻，乃因前世因果，互相欠債所致。夫妻意見不合相互爭吵時，常用這句話來勸雙方姻緣...  slang
# ..                                                 ...    ...
# 375  有樣學樣，沒樣自己想。意為有榜樣可學就依樣畫葫蘆，否則就自己想辦法；或指除了模仿他人，也應自...  slang
# 376               有孩子是命運的安排，沒孩子是天註定的。用來安慰膝下無子的人不要過於強求。  slang
# 377                      有度量就有福氣。指有度量的人自然會受到上天眷顧，得到賜福。  slang
# 378  燒香拜佛就會得到神佛保佑，吃藥就會有療效。比喻只要努力或是付出，就會有所收穫或是助益。亦即一...  slang
# 379  有來自唐山的父系祖先，沒有來自唐山的母系祖先。清初在渡臺禁令下，來臺開墾者多為單身的男性，往...  slang
#
#                                              href
# 0    https://sutian.moe.edu.tw//zh-hant/su/27204/
# 1    https://sutian.moe.edu.tw//zh-hant/su/27161/
# 2    https://sutian.moe.edu.tw//zh-hant/su/27162/
# 3    https://sutian.moe.edu.tw//zh-hant/su/27164/
# 4    https://sutian.moe.edu.tw//zh-hant/su/27093/
# ..                                            ...
# 375  https://sutian.moe.edu.tw//zh-hant/su/27009/
# 376  https://sutian.moe.edu.tw//zh-hant/su/27003/
# 377  https://sutian.moe.edu.tw//zh-hant/su/27008/
# 378  https://sutian.moe.edu.tw//zh-hant/su/27010/
# 379  https://sutian.moe.edu.tw//zh-hant/su/27006/
#
# [380 rows x 6 columns]

# %%
# Loop through the data frame, call API for translation
for i in range(len(df)):
    chinese = df.at[i, '釋義']
    
    response = requests.post(
        "http://localhost:8000/translate/invoke",
        json = {
            'input': {'Definition' : chinese}}
    )
    translated_def = response.json()['output']['content']
    df.at[i, '釋義'] = translated_def

# %%
df
# Out:
#       序號              詞目                                                 音讀  \
# 0      1           鴨仔聽雷。                                   Ah-á thiann luî.
# 1      2          愛拚才會贏。                             Ài piànn tsiah ē iânn.
# 2      3        愛媠毋驚流鼻水。                    Ài-suí m̄ kiann lâu phīnn-tsuí.
# 3      4   暗頓減食一口，活甲九十九。  Àm-tǹg kiám tsia̍h tsi̍t kháu, ua̍h kah káu-ts...
# 4      5        翁仔某是相欠債。                        Ang-á-bóo sī sio-khiàm-tsè.
# ..   ...             ...                                                ...
# 375  376     有樣看樣，無樣家己想。           Ū iūnn khuànn iūnn, bô iūnn ka-kī siūnn.
# 376  377    有囝有囝命，無囝天註定。     Ū kiánn ū kiánn miā, bô kiánn thinn tsù-tiānn.
# 377  378          有量就有福。                                  Ū-liōng tō ū hok.
# 378  379  有燒香有保庇，有食藥有行氣。    Ū sio-hiunn ū pó-pì, ū tsia̍h io̍h ū kiânn-khì.
# 379  380      有唐山公，無唐山媽。               Ū Tn̂g-suann kong, bô Tn̂g-suann má.
#
#                                                     釋義   tags  \
# 0    "Heard the thunder, but did not know what it w...  slang
# 1    You have to work hard to win. It is a metaphor...  slang
# 2    In order to show off their beautiful figure, e...  slang
# 3    Eating a little less for dinner, live to ninet...  slang
# 4    In this life, being married is due to karmic t...  slang
# ..                                                 ...    ...
# 375  Imitating others or coming up with your own id...  slang
# 376  Having children is fate's arrangement, not hav...  slang
# 377  If you have tolerance, you will have good fort...  slang
# 378  "Burning incense and worshipping Buddha will r...  slang
# 379  Paternal ancestors from Tangshan, no maternal ...  slang
#
#                                              href
# 0    https://sutian.moe.edu.tw//zh-hant/su/27204/
# 1    https://sutian.moe.edu.tw//zh-hant/su/27161/
# 2    https://sutian.moe.edu.tw//zh-hant/su/27162/
# 3    https://sutian.moe.edu.tw//zh-hant/su/27164/
# 4    https://sutian.moe.edu.tw//zh-hant/su/27093/
# ..                                            ...
# 375  https://sutian.moe.edu.tw//zh-hant/su/27009/
# 376  https://sutian.moe.edu.tw//zh-hant/su/27003/
# 377  https://sutian.moe.edu.tw//zh-hant/su/27008/
# 378  https://sutian.moe.edu.tw//zh-hant/su/27010/
# 379  https://sutian.moe.edu.tw//zh-hant/su/27006/
#
# [380 rows x 6 columns]

# %%
df.to_csv('data.csv', sep='|', index=False)
